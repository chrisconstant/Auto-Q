# %%
import pandas as pd

df = pd.read_csv("../../results/windturbinegearbox/genai_questions_bank_windturbinegearbox_llama.csv")
print (df.shape)
df['len'] = df['questions'].apply(lambda x: len(x.split(' ')))
import numpy as np
print (np.mean(df['len']))

df1 = pd.read_csv("../../results/windturbinegearbox/genai_questions_answer_ds_bank_windturbinegearbox_llama.csv")
df1['len'] = df1['answers'].apply(lambda x: len(x.split(' ')))
print (np.mean(df1['len']))
print (df1.shape)

df2 = pd.read_csv("../../results/windturbinegearbox/genai_questions_answer_sme_bank_windturbinegearbox_llama.csv")
df2['len'] = df2['answers'].apply(lambda x: len(x.split(' ')))
print (np.mean(df2['len']))
print (df2.shape)
# Out:
# (2969, 2)
# 27.223644324688447
# 559.1857923497267
# (183, 4)
# 508.97945205479454
# (146, 4)

# %%
# Out:
# (183, 3)

# %%
import pandas as pd

df = pd.read_csv("../../results/aircompressor/genai_questions_bank_aircompressor_llama.csv")
print (df.shape)
df['len'] = df['questions'].apply(lambda x: len(x.split(' ')))
import numpy as np
print (np.mean(df['len']))

df1 = pd.read_csv("../../results/aircompressor/genai_questions_answer_ds_bank_aircompressor_llama.csv")
df1['len'] = df1['answers'].apply(lambda x: len(x.split(' ')))
print (np.mean(df1['len']))
print (df1.shape)

df2 = pd.read_csv("../../results/aircompressor/genai_questions_answer_sme_bank_aircompressor_llama.csv")
df2['len'] = df2['answers'].apply(lambda x: len(x.split(' ')))
print (np.mean(df2['len']))
print (df2.shape)
# Out:
# (2847, 2)
# 25.805409202669477
# 327.2043795620438
# (137, 4)
# 316.19209039548025
# (177, 4)

# %%
import pandas as pd

df = pd.read_csv("../../results/windturbinegearbox/genai_questions_bank_windturbinegearbox_mixtral.csv")
print (df.shape)
# Out:
# (6617, 2)
