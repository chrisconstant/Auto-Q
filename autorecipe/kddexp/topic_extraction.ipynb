# %%
import pandas as pd
df = pd.read_csv('../test/genai_questions_809156896092057937.csv')
#df = pd.read_csv('../test/genai_questions_311016922297059474.csv')
questions = df['questions'].to_list()
print (questions)
# Out:
# ['What is the typical failure rate and common failure modes of wind turbine gearboxes?', 'What type of sensor data is collected from the wind turbine gearbox, such as temperature, vibration, or acoustic?', 'What is the sampling frequency of the sensor data?', 'Are there any specific performance metrics or thresholds for the wind turbine gearbox that should be considered when building the anomaly model?', 'Is there any historical data on past failures or anomalies in the wind turbine gearbox that can be used for training the model?', 'Are there any specific environmental or operational conditions that could affect the performance of the wind turbine gearbox and should be considered in the anomaly model?', 'Are there any regulatory or safety requirements that need to be considered when building the anomaly model?', 'Are there any specific communication protocols or data formats used for the sensor data that need to be considered when building the anomaly model?', 'Are there any other systems or components that interact with the wind turbine gearbox that should be considered when building the anomaly model?', 'Are there any specific data preprocessing or feature engineering techniques that should be applied to the sensor data before building the anomaly model?', 'Are there any specific maintenance or repair strategies that should be considered after an anomaly is detected in the wind turbine gearbox?', 'Are there any external factors, such as weather conditions or operating conditions, that could affect the gearbox performance and should be considered in the anomaly detection model?', 'What are the potential consequences of a gearbox failure, such as downtime, repair costs, and safety risks, and how can an anomaly detection model help mitigate those risks?', 'Are there any regulatory or compliance requirements related to the wind turbine gearbox performance and how can an anomaly detection model help meet those requirements?', 'Are there any specific failure modes that are more critical or common than others in the wind turbine gearbox and how can the sensor data help detect those failures?', 'What are the specific sensors present in the wind turbine system that monitor the condition of the gearbox, such as temperature, vibration, or oil quality sensors?', 'How is the data from the sensors currently being used for maintenance and what additional insights could be gained from an anomaly detection model?', 'How frequently are these sensors taking measurements and is there any specific time of the day or operation that is critical for monitoring?', 'What are the normal operating ranges for each of these sensors and how much deviation from these ranges would be considered an anomaly?', 'Have there been any past failures in the gearbox and what were the sensor readings leading up to those failures?', 'Can you provide more specific details on how the design, operating conditions, and maintenance practices of the wind turbine gearbox affect the specific details of the failure modes, reasons, codes, and degradation mechanisms?', "How can the FMEA be integrated with other reliability engineering tools, such as Reliability-Centered Maintenance (RCM) or Fault Tree Analysis (FTA), to provide a comprehensive view of the wind turbine gearbox's reliability?", 'Can you provide more details on the failure reasons, such as insufficient lubrication, overloading, high temperatures, vibration, and contamination of the lubricant, and how they contribute to the failure modes?', 'Can you explain the process of failure modes and effects analysis (FMEA) in identifying the specific component, failure mode, failure reason, failure code, and degradation mechanism in wind turbine gearboxes?', 'How can domain experts and engineers collaborate effectively in selecting the most appropriate machine learning algorithm or technique for building an anomaly detection model for wind turbine gearboxes?', 'How can the wind turbine gearbox be designed and maintained to p ...

# %%
from datasets import load_dataset

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

# We select a subsample of 5000 abstracts from ArXiv
docs = questions

# We define a number of topics that we know are in the documents
zeroshot_topic_list = ['failures', 'components']

# We fit our model using the zero-shot topics
# and we define a minimum similarity. For each document,
# if the similarity does not exceed that value, it will be used
# for clustering instead.
topic_model = BERTopic(
    embedding_model="thenlper/gte-large", 
    min_topic_size=15,
    zeroshot_topic_list=zeroshot_topic_list,
    zeroshot_min_similarity=.85,
    representation_model=KeyBERTInspired()
)
topics, _ = topic_model.fit_transform(docs)
# Out:
# Downloading .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# Downloading 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# Downloading README.md:   0%|          | 0.00/67.9k [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# Downloading onnx/config.json:   0%|          | 0.00/632 [00:00<?, ?B/s]
# Downloading model.onnx:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading onnx/tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading onnx/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/670M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]

# %%
ans = topic_model.get_topic_info()

# %%
topicans = ans['Representation'].to_list()

# %%
for item in topicans:
    print (item)
# Out:
# ['severity', 'failure', 'catastrophic', 'critical', 'rating', 'minor', 'scale', 'marginal', 'rated', 'factors']
# ['components', 'gearbox', 'subcomponents', 'critical', 'failures', 'monitored', 'turbine', '', '', '']
# ['gearboxes', 'anomaly', 'gearbox', 'deviations', 'turbine', 'model', 'components', 'faults', 'mechanical', 'systems']
# ['gearboxes', 'gearbox', 'failures', 'modes', 'reliability', 'faults', 'fmea', 'turbine', 'sensors', 'gear']
# ['anomaly', 'anomalies', 'sensors', 'data', 'model', 'protocols', 'metrics', 'security', 'sensor', 'requirements']
# ['gearboxes', 'gearbox', 'anomaly', 'anomalies', 'turbines', 'turbine', 'monitoring', 'detection', 'insights', 'maintenance']
# ['gearboxes', 'maintenance', 'gearbox', 'lubrication', 'oil', 'monitoring', 'analyzing', 'lubricating', 'analyzed', 'inspections']
# ['gearboxes', 'gearbox', 'compliance', 'regulatory', 'standards', 'compliant', 'regulations', 'monitoring', 'turbine', 'requirements']
# ['turbines', 'anomaly', 'turbine', 'wind', 'operational', 'detection', 'energy', 'alerts', 'reliability', 'compliance']
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ans
# Out:
#    Topic  Count                                           Name  \
# 0      0     17                                       failures
# 1      1      2                                     components
# 2      2     33       -1_gearboxes_gearbox_detection_detecting
# 3      3    253              0_gearboxes_gearbox_sensors_modes
# 4      4    161          1_gearboxes_anomalies_gearbox_anomaly
# 5      5    128                2_data_anomaly_sensors_security
# 6      6     34        3_gearboxes_maintenance_gearbox_prevent
# 7      7     26  4_lubrication_lubricating_gearboxes_lubricant
# 8      8     19                     5_fmea_accuracy_field_data
# 9      9     19     6_gearboxes_gearbox_maintenance_monitoring
#
#                                       Representation  \
# 0  [failures, failure, degradation, modes, risk, ...
# 1  [gearbox, components, subcomponents, , , , , ,...
# 2  [gearboxes, gearbox, detection, detecting, alg...
# 3  [gearboxes, gearbox, sensors, modes, sensor, f...
# 4  [gearboxes, anomalies, gearbox, anomaly, detec...
# 5  [data, anomaly, sensors, security, anomalies, ...
# 6  [gearboxes, maintenance, gearbox, prevent, rel...
# 7  [lubrication, lubricating, gearboxes, lubrican...
# 8  [fmea, accuracy, field, data, analysis, reliab...
# 9  [gearboxes, gearbox, maintenance, monitoring, ...
#
#                                  Representative_Docs
# 0  [Can you provide more details on the failure r...
# 1  [What are the critical components and subcompo...
# 2  [Are there any specific machine learning algor...
# 3  [What are the most common failure modes in win...
# 4  [What are the common causes of wind turbine ge...
# 5  [Are there any specific data security or priva...
# 6  [What are the recommended maintenance practice...
# 7  [What are the common causes of insufficient lu...
# 8  [How the data collected from the field is used...
# 9  [Can you explain the significance of detecting...
