# %%
import pandas as pd
df = pd.read_csv('../test/genai_questions_809156896092057937.csv')
#df = pd.read_csv('../test/genai_questions_311016922297059474.csv')
df = pd.read_csv("../../results/windturbinegearbox/genai_questions_bank_windturbinegearbox_llama.csv")
questions = df['questions'].to_list()
print (len(questions))
# Out:
# 2969

# %%
from datasets import load_dataset

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

# We select a subsample of 5000 abstracts from ArXiv
docs = questions

# We define a number of topics that we know are in the documents
zeroshot_topic_list = ['failures', 'components']

# We fit our model using the zero-shot topics
# and we define a minimum similarity. For each document,
# if the similarity does not exceed that value, it will be used
# for clustering instead.
topic_model = BERTopic(
    embedding_model="thenlper/gte-large", 
    min_topic_size=15,
    zeroshot_topic_list=zeroshot_topic_list,
    zeroshot_min_similarity=.85,
    representation_model=KeyBERTInspired()
)
topics, _ = topic_model.fit_transform(docs)

# %%
ans = topic_model.get_topic_info()

# %%
topicans = ans['Representation'].to_list()

# %%
for item in topicans:
    print (item)
# Out:
# ['failures', 'failure', 'modes', 'components', 'challenges', 'critical', 'limitations', 'examples', 'component', 'anomalies']
# ['components', 'component', 'failure', 'modes', 'cascading', 'system', 'anomaly', 'effects', '', '']
# ['gearboxes', 'sensors', 'monitoring', 'gearbox', 'maintenance', 'sensor', 'systems', 'components', 'system', 'turbine']
# ['lubrication', 'gearboxes', 'lubricants', 'lubricant', 'gearbox', 'maintenance', 'turbines', 'reliability', 'turbine', 'oil']
# ['gearboxes', 'gearbox', 'analytics', 'anomalies', 'anomaly', 'algorithms', 'autoencoders', 'ai', 'predicting', 'detection']
# ['sensors', 'sensor', 'gearbox', 'misalignment', 'monitoring', 'faults', 'bearing', 'vibration', 'data', 'gear']
# ['gearboxes', 'gearbox', 'anomalies', 'anomaly', 'maintenance', 'systems', 'challenges', 'detection', 'turbine', 'detecting']
# ['gearboxes', 'gearbox', 'humidity', 'moisture', 'winds', 'climate', 'temperatures', 'turbines', 'reliability', 'weather']
# ['gearboxes', 'gearbox', 'failures', 'modes', 'turbines', 'turbine', 'failure', 'maintenance', 'components', 'blades']
# ['sensors', 'gearboxes', 'sensor', 'accelerometers', 'sensing', 'gearbox', 'turbines', 'monitoring', 'turbine', 'systems']
# ['maintenance', 'gearboxes', 'turbines', 'reliability', 'gearbox', 'strategies', 'implementation', 'turbine', 'failures', 'implemented']
# ['gearboxes', 'gearbox', 'bearing', 'maintenance', 'analysis', 'vibration', 'monitoring', 'oil', 'faults', 'testing']
# ['anomaly', 'anomalies', 'maintenance', 'predict', 'expert', 'expertise', 'predictions', 'predictive', 'detection', 'algorithms']
# ['gearboxes', 'bearings', 'bearing', 'gearwheels', 'gearbox', 'gears', 'faults', 'failures', 'defects', 'turbine']
# ['gearboxes', 'gearbox', 'gears', 'materials', 'bearings', 'material', 'durability', 'turbines', 'components', 'manufacturing']
# ['gearboxes', 'gearbox', 'technologies', 'reliability', 'bearing', 'maintenance', 'technology', 'trends', 'turbine', 'coupling']
# ['gearboxes', 'maintenance', 'gearbox', 'repairs', 'repairing', 'repair', 'replacing', 'costs', 'cost', 'replacement']
# ['sensors', 'gearboxes', 'sensor', 'gearbox', 'anomalies', 'monitoring', 'turbine', 'detection', 'detecting', 'data']
# ['maintenance', 'gearboxes', 'gearbox', 'tasks', 'operating', 'turbine', 'frequent', 'parts', 'schedules', 'inspections']
# ['sensors', 'sensor', 'failures', 'trends', 'data', 'anomalies', 'failure', 'patterns', 'examples', 'occurs']
# ['sensors', 'sensor', 'humidity', 'accelerometers', 'temperature', 'accuracy', 'data', 'detection', 'environmental', 'metrics']
# ['maintenance', 'turbines', 'predictive', 'challenges', 'reliability', 'insights', 'efficiency', 'implementations', 'monitoring', 'downtime']
# ['maintenance', 'gearbox', 'reliability', 'gear', 'practices', 'downtime', 'ensure', 'cleaning', 'failures', 'preventing']
# ['sensors', 'imputation', 'sensor', 'data', 'missing', 'incomplete', 'model', 'impute', 'regression', 'system']
# ['maintenance', 'gearboxes', 'prioritizing', 'prioritization', 'prioritize', 'gearbox', 'priority', 'task', 'tasks', 'scheduling']
# ['gearboxes', 'maintenance', 'gearbox', 'predictive', 'reliability', 'failures', 'systems', 'monitoring', 'turbine', 'strategies']
# ['lubrication', 'lubricant', 'gearbox', 'lubricate', 'lubricated', 'systems', 'system', 'failures', 'components', 'overheating']
# ['thermography', 'maintenance', 'inspection', 'vibration', 'monitoring', 'oil', 'testing', 'analysis', 'inspections', 'gearbox']
# ['lubrication', 'humidity', 'temperatures', 'gearbox', 'temperature', 'cooling', 'environmental', 'factors', 'fluctuations', 'rain']
# ['sensors', 'monitoring', 'sensor', 'accuracy', 'reliability', 'calibration', 'data', 'reliable', 'verify', 'calibrating']
# ['misalignment', 'gearboxes', 'misaligned', 'bearing', 'alignment', 'gearbox', 'gears', 'gearwheel', 'mechanical', 'shaft']
# ['gearboxes', 'gearbox', 'gears', 'sensors', 'failures', 'modes', 'mode', 'sensor', 'faults', 'gear']
# ['gearboxes', 'gearbox', 'gears', 'components', 'parts', 'failures', 'turbine', 'failure', 'defects', 'manufacturing']
# ['sensors', 'sensor', 'anomalies', 'anomaly', 'detection', 'data', 'outliers', 'algorithms', 'detect', 'intelligence']
# ['gearboxes', 'monitoring', 'gearbox', 'maintenance', 'gear', 'technologies', 'testing', 'diagnostics', 'failures', 'turbine']
# ['gearboxes', 'degradation', 'gearbox', 'reliability', 'mechanisms', 'components', 'gear', 'bearing', 'corrosion', 'turbine']
# ['gearboxes', 'electrical', 'gearbox', 'turbine', 'failures', 'generator', 'components', 'defects', 'motor', 'parts']
# ['detectability', 'severity', 'rating', 'ratings', 'criteria', 'likelihood', 'kpis', 'summary', 'preventive', 'metrics']
# ['gearboxes', 'turbines', 'turbine', 'gearbox', 'failures', 'modes', 'wind', 'operational', 'operating', 'failure']
# ['maintenance', 'training', 'maintain', 'skills', 'trained', 'certification', 'personnel', 'certifications', 'competence', 'equipped']
# ['gearboxes', 'sensors', 'gearbox', 'humidity', 'anomalies', 'reliability', 'wind', 'temperature', 'anomaly', 'environmental']
# ['anomalies', 'anomaly', 'negatives', 'detection', 'likelihood', 'positives', 'model', 'errors', 'prediction', 'detect']
# ['gearboxes', 'detectability', 'gearbox', 'severity', 'turbines', 'rating', 'fmea', 'failures', 'ratings', 'criteria']
# ['gearboxes', 'standards', 'maintenance', 'gearbox', 'regulatory', 'regulations', 'industry', 'maintaining', 'reliability', 'compliance']
# ['anomaly', 'metrics', 'anomalies', 'benchmarks', 'detection', 'monitored', 'evaluated', 'effectiveness', 'performance', 'model']
# ['gearboxes', 'standards', 'standardization', 'anomalies', 'regulatory', 'anomaly', 'compliance', 'regulations', 'maintenance', 'requirements']
# ['turbines', 'turbine', 'monitoring', 'anomaly', 'systems', 'scada', 'detection', 'renewable', 'maintenance', 'wind']
# ['fmea', 'gearboxes', 'fea', 'failures', 'reliability', 'modes', 'failure', 'mode', 'fta', 'analysis']
# ['gearboxes', 'gearbox', 'turbines', 'failures', 'reliability', 'turbine', 'efficiency', 'failure', 'profitability', 'energy']
# ['gearbox', 'maintenance', 'indicators', 'turbine', 'gear', 'signs', 'bearing', 'failures', 'degradation', 'wind']

# %%
ans['Representative_Docs'][4]
# Out:
# ['How do machine learning algorithms improve the accuracy of anomaly detection in wind turbine gearbox sensor data?',
#  'Can you provide examples of specific machine learning algorithms and techniques that have been used for anomaly detection in wind turbine gearbox sensor data?',
#  'Can you explain the specific machine learning algorithms used for anomaly detection and predictive maintenance in wind turbine gearboxes?']

# %%
ans.to_csv('ResTopic.csv',index=False)

# %%
top_10_records = ans.nlargest(10, 'Count')

# %%
top_10_records.to_csv('top10_recipe.csv',index=False)
