# %%
# https://huggingface.co/datasets/RUCAIBox/Question-Answering

dbset = [
    "squad",
    "coqa",
    "nq",
    "webq",
    "nqa",
    "marco",
    "newsqa",
    "hotpotqa",
    "msqg",
    "quac",
]
excludedset = ["tqa"]

huggingfacedb = [
    "squad_v2",
    "coqa",
    #"ms_marco",
    #"newsqa",
    "nq_open",
    "quac",
    "web_questions",
]

# %%
# Squard 2 dataste
from datasets import load_dataset
dataset = load_dataset('squad_v2', split='train')
pdb = dataset.to_pandas()
print (pdb.columns, pdb.shape)

pdb['question'].to_csv('squad_v2_q.csv', index=False)
# Out:
# Found cached dataset parquet (C:/Users/1J1870897/.cache/huggingface/datasets/parquet/squad_v2-1cbbf6fc1244ca52/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# Index(['id', 'title', 'context', 'question', 'answers'], dtype='object') (130319, 5)

# %%
from datasets import load_dataset
dataset = load_dataset('web_questions', split='train')
pdb = dataset.to_pandas()
print (pdb.columns, pdb.shape)
print(pdb['question'])

pdb['question'].to_csv('web_questions_q.csv', index=False)
# Out:
# Found cached dataset parquet (C:/Users/1J1870897/.cache/huggingface/datasets/parquet/web_questions-b03923b007ebe8e9/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# Index(['url', 'question', 'answers'], dtype='object') (3778, 3)
# 0              what is the name of justin bieber brother?
# 1       what character did natalie portman play in sta...
# 2                           what state does selena gomez?
# 3             what country is the grand bahama island in?
# 4                  what kind of money to take to bahamas?
#                               ...
# 3773                   where did sir donald bradman live?
# 3774    what are the holydays of obligation in the cat...
# 3775              what is the name of the broncos mascot?
# 3776    what caused the russian financial crisis of 1998?
# 3777               what kind government does the us have?
# Name: question, Length: 3778, dtype: object

# %%
from datasets import load_dataset
dataset = load_dataset('nq_open', split='train')
pdb = dataset.to_pandas()
print (pdb.columns, pdb.shape)
print (pdb['question'])

pdb['question'].to_csv('nq_open_q.csv', index=False)
# Out:
# Found cached dataset parquet (C:/Users/1J1870897/.cache/huggingface/datasets/parquet/nq_open-c50f491c21b7079c/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# Index(['question', 'answer'], dtype='object') (87925, 2)
# 0                 where did they film hot tub time machine
# 1         who has the right of way in international waters
# 2                  who does annie work for attack on titan
# 3        when was the immigration reform and control ac...
# 4                    when was puerto rico added to the usa
#                                ...
# 87920         who was the first prime minister of tanzania
# 87921    what is the name of the football team in facin...
# 87922                         who sang lead on when i'm 64
# 87923         what is the style of this boy by the beatles
# 87924                   nigeria was given it's name by who
# Name: question, Length: 87925, dtype: object

# %%
from datasets import load_dataset
dataset = load_dataset('hotpot_qa', 'distractor')
pdb = dataset['train'].to_pandas()
print (pdb.columns, pdb.shape)
print (pdb['question'])

pdb['question'].to_csv('hotpot_q.csv', index=False)

# %%
from datasets import load_dataset

for db in huggingfacedb:
    dataset = load_dataset(db, split='train')
    pdb = dataset.to_pandas()
    print (db, pdb.columns, pdb.shape)
    #qlist = pdb['question'].to_list()
    #print (db, len(qlist))
# Out:
# Found cached dataset parquet (C:/Users/1J1870897/.cache/huggingface/datasets/parquet/squad_v2-1cbbf6fc1244ca52/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# squad_v2 Index(['id', 'title', 'context', 'question', 'answers'], dtype='object') (130319, 5)
# Found cached dataset parquet (C:/Users/1J1870897/.cache/huggingface/datasets/parquet/coqa-5acf9d42f639286d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# coqa Index(['source', 'story', 'questions', 'answers'], dtype='object') (7199, 4)
# Found cached dataset parquet (C:/Users/1J1870897/.cache/huggingface/datasets/parquet/nq_open-c50f491c21b7079c/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# nq_open Index(['question', 'answer'], dtype='object') (87925, 2)
# Found cached dataset quac (C:/Users/1J1870897/.cache/huggingface/datasets/quac/plain_text/1.1.0/4170258e7e72d7c81bd6441b3f3489ea1544f0ff226ce61e22bb00c6e9d01fb6)
# ...

# %%
load_dataset('hotpot_qa', 'distractor')
# Out:
# ...
# Generating validation split:   0%|          | 0/7405 [00:00<?, ? examples/s]
# Dataset hotpot_qa downloaded and prepared to C:/Users/1J1870897/.cache/huggingface/datasets/hotpot_qa/distractor/1.0.0/133b9501f892e5193babbad937bee3b4899deb4691ef4d791e6ac0111c875bb5. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context'],
#         num_rows: 90447
#     })
#     validation: Dataset({
#         features: ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context'],
#         num_rows: 7405
#     })
# })
